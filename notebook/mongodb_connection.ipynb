# %%
import os

import numpy as np

import pandas as pd

# %%
PROJECT_DIR = r"C:\Users\Surface\Desktop\data-science-project\ML-Project\MLOps-Flight-Price-Prediction"
DATA_DIR = "notebook"

# %%
def get_data(name):
	file_name = f"{name}.csv"
	file_path = os.path.join(PROJECT_DIR, DATA_DIR, file_name)
	return pd.read_csv(file_path)

# %%
flights = get_data("flight_price")
flights
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
flights.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
import pymongo

# %%
# df should be converted into dict before we push it to mongodb

data = flights.to_dict(orient='records')

# %%
data
# Out:
# [{'Airline': 'IndiGo',
#   'Date_of_Journey': '24/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '22:20',
#   'Arrival_Time': '01:10 22 Mar',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3897},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '1/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → IXR → BBI → BLR',
#   'Dep_Time': '05:50',
#   'Arrival_Time': '13:15',
#   'Duration': '7h 25m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 7662},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '9/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → LKO → BOM → COK',
#   'Dep_Time': '09:25',
#   'Arrival_Time': '04:25 10 Jun',
#   'Duration': '19h',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 13882},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → NAG → BLR',
#   'Dep_Time': '18:05',
#   'Arrival_Time': '23:30',
#   'Duration': '5h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6218},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '01/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → NAG → DEL',
#   'Dep_Time': '16:50',
#   'Arrival_Time': '21:35',
#   'Duration': '4h 45m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13302},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '09:00',
#   'Arrival_Time': '11:25',
#   'Duration': '2h 25m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3873},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '18:55',
#   'Arrival_Time': '10:25 13 Mar',
#   'Duration': '15h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 11087},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '01/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '08:00',
#   'Arrival_Time': '05:05 02 Mar',
#   'Duration': '21h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 22270},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '08:55',
#   'Arrival_Time': '10:25 13 Mar',
#   'Duration': '25h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 11087},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '11:25',
#   'Arrival_Time': '19:15',
#   'Duration': '7h 50m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 8625},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '1/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BLR → COK',
#   'Dep_Time': '09:45',
#   'Arrival_Time': '23:00',
#   'Duration': '13h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 8907},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '18/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '20:20',
#   'Arrival_Time': '22:55',
#   'Duration': '2h 35m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4174},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '13:55',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4667},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '9/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '21:10',
#   'Arrival_Time': '09:20 10 May',
#   'Duration': '12h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 9663},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '24/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '17:15',
#   'Arrival_Time': '19:50',
#   'Duration': '2h 35m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4804},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '3/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → AMD → BOM → COK',
#   'Dep_Time': '16:40',
#   'Arrival_Time': '19:15 04 Mar',
#   'Duration': '26h 35m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 14011},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '15/04/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → PNQ → COK',
#   'Dep_Time': '08:45',
#   'Arrival_Time': '13:15',
#   'Duration': '4h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5830},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '14:00',
#   'Arrival_Time': '12:35 13 Jun',
#   'Duration': '22h 35m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10262},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '12/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → CCU → BOM → COK',
#   'Dep_Time': '20:15',
#   'Arrival_Time': '19:15 13 Jun',
#   'Duration': '23h',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 13381},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '16:00',
#   'Arrival_Time': '12:35 28 May',
#   'Duration': '20h 35m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 12898},
#  {'Airline': 'GoAir',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '14:10',
#   'Arrival_Time': '19:20',
#   'Duration': '5h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 19495},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → COK → DEL',
#   'Dep_Time': '22:00',
#   'Arrival_Time': '13:20 19 Mar',
#   'Duration': '15h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6955},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '04:00',
#   'Arrival_Time': '06:50',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3943},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '1/05/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '18:55',
#   'Arrival_Time': '21:50',
#   'Duration': '2h 55m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4823},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '18:55',
#   'Arrival_Time': '08:15 07 May',
#   'Duration': '13h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 7757},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '9/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → IDR → BOM → COK',
#   'Dep_Time': '21:25',
#   'Arrival_Time': '12:35 10 Jun',
#   'Duration': '15h 10m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 13292},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '1/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → LKO → COK',
#   'Dep_Time': '21:50',
#   'Arrival_Time': '03:35 02 Jun',
#   'Duration': '5h 45m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 8238},
#  {'Airline': 'GoAir',
#   'Date_of_Journey': '15/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '07:00',
#   'Arrival_Time': '12:55',
#   'Duration': '5h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 7682},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '18/06/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '09:45',
#   'Arrival_Time': '12:35',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4668},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '09:20',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3687},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '18/06/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '09:20',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3687},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '1/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → GAU → DEL → BLR',
#   'Dep_Time': '09:50',
#   'Arrival_Time': '23:15',
#   'Duration': '13h 25m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 13227},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '6/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '04:00',
#   'Arrival_Time': '06:50',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4423},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → NAG → BOM → COK',
#   'Dep_Time': '14:35',
#   'Arrival_Time': '12:35 16 Jun',
#   'Duration': '22h',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10919},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '12:35',
#   'Duration': '5h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 12373},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '27/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '10:35',
#   'Arrival_Time': '21:00',
#   'Duration': '10h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5894},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → MAA → BLR',
#   'Dep_Time': '15:05',
#   'Arrival_Time': '20:20',
#   'Duration': '5h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 4649},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '14:15',
#   'Arrival_Time': '16:45',
#   'Duration': '2h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 6245},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '06/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '07:00',
#   'Arrival_Time': '13:15',
#   'Duration': '6h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 19225},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '19:00',
#   'Duration': '11h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14924},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → COK',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '18:10',
#   'Duration': '11h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9646},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '15/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '06:45',
#   'Arrival_Time': '15:15',
#   'Duration': '8h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 8714},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '20:55',
#   'Arrival_Time': '19:00 19 May',
#   'Duration': '22h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 12373},
#  {'Airline': 'Air Asia',
#   'Date_of_Journey': '6/05/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '11:10',
#   'Arrival_Time': '13:55',
#   'Duration': '2h 45m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3383},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '09:00',
#   'Arrival_Time': '21:00',
#   'Duration': '12h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13062},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '24/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '05:45',
#   'Arrival_Time': '08:35',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No check-in baggage included',
#   'Price': 3527},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '04:00',
#   'Arrival_Time': '06:50',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3943},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '3/05/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '13:55',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4667},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '15/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → HYD → BLR',
#   'Dep_Time': '19:00',
#   'Arrival_Time': '11:05 16 May',
#   'Duration': '16h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6117},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '27/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → AMD → BOM → COK',
#   'Dep_Time': '23:05',
#   'Arrival_Time': '19:00 28 Jun',
#   'Duration': '19h 55m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 11150},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '9/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → COK',
#   'Dep_Time': '11:00',
#   'Arrival_Time': '14:15',
#   'Duration': '3h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 7202},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '1/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → DEL → BLR',
#   'Dep_Time': '09:35',
#   'Arrival_Time': '10:55 02 May',
#   'Duration': '25h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 12121},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '24/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '22:20',
#   'Arrival_Time': '01:10 28 Mar',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4377},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '18/06/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '21:15',
#   'Arrival_Time': '00:15 19 Jun',
#   'Duration': '3h',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3943},
#  {'Airline': 'Air Asia',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '23:55',
#   'Arrival_Time': '02:45 04 Apr',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4483},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/03/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '19:45',
#   'Arrival_Time': '12:00 25 Mar',
#   'Duration': '16h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14231},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '01/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → AMD → DEL',
#   'Dep_Time': '08:50',
#   'Arrival_Time': '23:55',
#   'Duration': '15h 5m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 17345},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '09:20',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 7414},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '6/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '19:00',
#   'Arrival_Time': '01:30 07 May',
#   'Duration': '6h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 8073},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → DEL → HYD',
#   'Dep_Time': '15:40',
#   'Arrival_Time': '16:45 07 Mar',
#   'Duration': '25h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 12395},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '6/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '09:25',
#   'Arrival_Time': '21:50',
#   'Duration': '12h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 8366},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → MAA → COK',
#   'Dep_Time': '06:05',
#   'Arrival_Time': '09:25 04 Apr',
#   'Duration': '27h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5117},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '08:45',
#   'Arrival_Time': '19:00',
#   'Duration': '10h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 12524},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '15/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '15:00',
#   'Arrival_Time': '01:30 16 May',
#   'Duration': '10h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 7191},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '24/05/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '09:20',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3687},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '10:35',
#   'Arrival_Time': '21:00',
#   'Duration': '10h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5894},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '24/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '09:45',
#   'Arrival_Time': '12:35',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 5403},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '6/05/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '13:55',
#   'Arrival_Time': '15:25',
#   'Duration': '1h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3625},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BHO → BOM → COK',
#   'Dep_Time': '05:55',
#   'Arrival_Time': '19:15',
#   'Duration': '13h 20m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 10861},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '12/03/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '13:20',
#   'Arrival_Time': '15:35',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 6297},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '1/06/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '08:30',
#   'Duration': '1h 25m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 5678},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '09/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '05:45',
#   'Arrival_Time': '08:15 13 Mar',
#   'Duration': '26h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 9134},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '19:00',
#   'Duration': '7h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10791},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → AMD → BOM → COK',
#   'Dep_Time': '23:05',
#   'Arrival_Time': '12:35 25 Jun',
#   'Duration': '13h 30m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 12819},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BLR → COK',
#   'Dep_Time': '05:05',
#   'Arrival_Time': '10:05',
#   'Duration': '5h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6893},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '09/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '09:50',
#   'Arrival_Time': '12:35',
#   'Duration': '2h 45m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 7240},
#  {'Airline': 'GoAir',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '14:30',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3898},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '06:25',
#   'Arrival_Time': '07:55',
#   'Duration': '1h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4049},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '17:30',
#   'Arrival_Time': '12:35 16 Jun',
#   'Duration': '19h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10262},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '08:20',
#   'Arrival_Time': '10:35',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No check-in baggage included',
#   'Price': 3332},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '9/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '21:10',
#   'Arrival_Time': '12:00 10 Jun',
#   'Duration': '14h 50m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10844},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '19:55',
#   'Arrival_Time': '22:35',
#   'Duration': '2h 40m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 7229},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '06:30',
#   'Arrival_Time': '04:40 07 May',
#   'Duration': '22h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13941},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '27/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '11:25',
#   'Arrival_Time': '21:00',
#   'Duration': '9h 35m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5894},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '09:00',
#   'Arrival_Time': '19:00',
#   'Duration': '10h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 10197},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '06/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '14:05',
#   'Arrival_Time': '11:25 07 Mar',
#   'Duration': '21h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 13712},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → MAA → COK',
#   'Dep_Time': '02:00',
#   'Arrival_Time': '07:25',
#   'Duration': '5h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5636},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → JAI → BOM → COK',
#   'Dep_Time': '09:40',
#   'Arrival_Time': '04:25 07 Jun',
#   'Duration': '18h 45m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 13014},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '1/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '08:25',
#   'Arrival_Time': '20:45',
#   'Duration': '12h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 7064},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → DEL → BLR',
#   'Dep_Time': '20:25',
#   'Arrival_Time': '14:25 25 May',
#   'Duration': '18h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10703},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → COK',
#   'Dep_Time': '13:15',
#   'Arrival_Time': '22:30',
#   'Duration': '9h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9646},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '02:15',
#   'Arrival_Time': '13:20',
#   'Duration': '11h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 17057},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '16:55',
#   'Arrival_Time': '10:25 13 Mar',
#   'Duration': '17h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13817},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BHO → BOM → COK',
#   'Dep_Time': '05:55',
#   'Arrival_Time': '19:15',
#   'Duration': '13h 20m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 13748},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '20:45',
#   'Arrival_Time': '23:20',
#   'Duration': '2h 35m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4880},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '21/06/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '05:15',
#   'Arrival_Time': '07:40',
#   'Duration': '2h 25m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3540},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '15/05/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '05:55',
#   'Arrival_Time': '08:35',
#   'Duration': '2h 40m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No check-in baggage included',
#   'Price': 3257},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '19:50',
#   'Arrival_Time': '22:50',
#   'Duration': '3h',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 6478},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '18/06/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '08:30',
#   'Duration': '1h 25m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 8040},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → ATQ → BOM → COK',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '12:35 13 Jun',
#   'Duration': '16h 35m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 14300},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '15/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '08:25',
#   'Arrival_Time': '20:45',
#   'Duration': '12h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14781},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '9/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '08:15 10 Jun',
#   'Duration': '12h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14939},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '20:55',
#   'Arrival_Time': '04:25 25 Jun',
#   'Duration': '7h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10262},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → MAA → BLR',
#   'Dep_Time': '14:35',
#   'Arrival_Time': '14:35 13 May',
#   'Duration': '24h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6528},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '1/05/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '06:10',
#   'Arrival_Time': '08:55',
#   'Duration': '2h 45m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 6121},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → JAI → BOM → COK',
#   'Dep_Time': '19:30',
#   'Arrival_Time': '04:25 19 May',
#   'Duration': '8h 55m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 13029},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '27/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '18:50',
#   'Duration': '7h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 11421},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '27/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '04:45',
#   'Arrival_Time': '19:15',
#   'Duration': '14h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 7574},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '9/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → JDH → BOM → COK',
#   'Dep_Time': '12:55',
#   'Arrival_Time': '19:15 10 May',
#   'Duration': '30h 20m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 11596},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → AMD → BOM → COK',
#   'Dep_Time': '23:05',
#   'Arrival_Time': '19:00 25 May',
#   'Duration': '19h 55m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 15129},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '18/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '14:05',
#   'Arrival_Time': '05:05 16 Mar',
#   'Duration': '15h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13555},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '12/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '18:55',
#   'Arrival_Time': '21:50',
#   'Duration': '2h 55m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 5780},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → DEL → BLR',
#   'Dep_Time': '20:20',
#   'Arrival_Time': '09:05 13 May',
#   'Duration': '12h 45m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9397},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '18:15',
#   'Arrival_Time': '04:25 07 Mar',
#   'Duration': '10h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 17024},
#  {'Airline': 'GoAir',
#   'Date_of_Journey': '27/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '07:00',
#   'Arrival_Time': '12:55',
#   'Duration': '5h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5281},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → COK',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '22:30',
#   'Duration': '15h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 10348},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → MAA → COK',
#   'Dep_Time': '17:20',
#   'Arrival_Time': '09:25 07 Mar',
#   'Duration': '16h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 12677},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '3/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '15:25',
#   'Arrival_Time': '01:35 04 Mar',
#   'Duration': '10h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 15147},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '12/06/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '07:00',
#   'Arrival_Time': '09:40',
#   'Duration': '2h 40m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4668},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '9/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '19:00',
#   'Duration': '11h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 15554},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '9/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '05:55',
#   'Arrival_Time': '08:35',
#   'Duration': '2h 40m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3971},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '3/05/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '15:00',
#   'Arrival_Time': '16:25',
#   'Duration': '1h 25m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3100},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '10:05 07 May',
#   'Duration': '14h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 9663},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '1/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '23:00',
#   'Arrival_Time': '19:15 02 Mar',
#   'Duration': '20h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 27430},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '05:15',
#   'Arrival_Time': '07:40',
#   'Duration': '2h 25m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3540},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BBI → BOM → BLR',
#   'Dep_Time': '12:00',
#   'Arrival_Time': '11:10 22 May',
#   'Duration': '23h 10m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 10676},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '14:05',
#   'Arrival_Time': '08:15 13 Jun',
#   'Duration': '18h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13044},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '12:00 07 May',
#   'Duration': '16h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14388},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '04:00',
#   'Arrival_Time': '06:50',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3943},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '14:45',
#   'Arrival_Time': '17:05',
#   'Duration': '2h 20m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3597},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → MAA → DEL',
#   'Dep_Time': '11:50',
#   'Arrival_Time': '19:50',
#   'Duration': '8h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5932},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '11:30',
#   'Arrival_Time': '04:25 16 Jun',
#   'Duration': '16h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10262},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → COK',
#   'Dep_Time': '14:40',
#   'Arrival_Time': '17:50',
#   'Duration': '3h 10m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 6216},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '20:25',
#   'Arrival_Time': '23:10',
#   'Duration': '2h 45m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4804},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '11:30',
#   'Arrival_Time': '01:30 22 May',
#   'Duration': '14h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14067},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → AMD → BOM → COK',
#   'Dep_Time': '19:10',
#   'Arrival_Time': '19:00 19 May',
#   'Duration': '23h 50m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 15129},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → NAG → BOM → COK',
#   'Dep_Time': '06:45',
#   'Arrival_Time': '04:25 07 Jun',
#   'Duration': '21h 40m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 13376},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '27/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → GOI → BOM → COK',
#   'Dep_Time': '22:00',
#   'Arrival_Time': '19:15 28 Jun',
#   'Duration': '21h 15m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 10441},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/05/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '06:00',
#   'Arrival_Time': '08:45',
#   'Duration': '2h 45m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 4030},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '3/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '08:00',
#   'Arrival_Time': '18:50',
#   'Duration': '10h 50m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 17024},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '9/04/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '17:30',
#   'Arrival_Time': '01:30 10 Apr',
#   'Duration': '8h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13017},
#  {'Airline': 'GoAir',
#   'Date_of_Journey': '6/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '23:30',
#   'Arrival_Time': '07:45 07 Jun',
#   'Duration': '8h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6686},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → MAA → COK',
#   'Dep_Time': '02:00',
#   'Arrival_Time': '07:25',
#   'Duration': '5h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5636},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '9/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → COK',
#   'Dep_Time': '07:35',
#   'Arrival_Time': '16:10',
#   'Duration': '8h 35m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6442},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → COK',
#   'Dep_Time': '13:05',
#   'Arrival_Time': '00:55 22 May',
#   'Duration': '11h 50m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9486},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '23:35 22 May',
#   'Duration': '27h 35m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10844},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → ATQ → BOM → COK',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '04:25 04 Jun',
#   'Duration': '8h 25m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 15318},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → MAA → COK',
#   'Dep_Time': '12:30',
#   'Arrival_Time': '09:25 04 Apr',
#   'Duration': '20h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5117},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '24/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BLR → COK',
#   'Dep_Time': '15:10',
#   'Arrival_Time': '20:00',
#   'Duration': '4h 50m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 6147},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '9/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '12:50',
#   'Arrival_Time': '21:00',
#   'Duration': '8h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 7005},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '22:20',
#   'Arrival_Time': '00:40 04 Apr',
#   'Duration': '2h 20m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3873},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BDQ → BOM → COK',
#   'Dep_Time': '18:25',
#   'Arrival_Time': '18:50 22 Mar',
#   'Duration': '24h 25m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 9270},
#  {'Airline': 'GoAir',
#   'Date_of_Journey': '27/06/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '14:30',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3898},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '08:25',
#   'Arrival_Time': '20:45',
#   'Duration': '12h 20m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14781},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '08:15 25 May',
#   'Duration': '12h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 8586},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '9/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → JAI → BOM → BLR',
#   'Dep_Time': '08:20',
#   'Arrival_Time': '07:55 10 May',
#   'Duration': '23h 35m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 10697},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '27/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → ATQ → BOM → COK',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '12:35 28 Jun',
#   'Duration': '16h 35m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 14300},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '03/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '18:55',
#   'Arrival_Time': '21:45',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 8855},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '16:30',
#   'Arrival_Time': '18:15 13 May',
#   'Duration': '25h 45m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10844},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '02:15',
#   'Arrival_Time': '04:25 07 Mar',
#   'Duration': '26h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 17024},
# ...
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '21:10',
#   'Arrival_Time': '10:05 13 May',
#   'Duration': '12h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13941},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '18:55',
#   'Arrival_Time': '04:40 22 May',
#   'Duration': '9h 45m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14388},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '18:55',
#   'Arrival_Time': '16:20 13 May',
#   'Duration': '21h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10844},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '3/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → COK',
#   'Dep_Time': '06:40',
#   'Arrival_Time': '22:20',
#   'Duration': '15h 40m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 11600},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '6/06/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '22:05',
#   'Arrival_Time': '00:25 07 Jun',
#   'Duration': '2h 20m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 5277},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '14:00',
#   'Arrival_Time': '04:25 04 Jun',
#   'Duration': '14h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10262},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '03/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '04:00',
#   'Arrival_Time': '06:50',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 6144},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '21:50',
#   'Arrival_Time': '04:25 04 Jun',
#   'Duration': '6h 35m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 12898},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '06:30',
#   'Arrival_Time': '04:40 13 May',
#   'Duration': '22h 10m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13941},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '14:00',
#   'Arrival_Time': '04:25 19 May',
#   'Duration': '14h 25m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 12373},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '3/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '17:10',
#   'Arrival_Time': '19:40',
#   'Duration': '2h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No check-in baggage included',
#   'Price': 3841},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → JAI → BOM → BLR',
#   'Dep_Time': '08:20',
#   'Arrival_Time': '07:55 19 May',
#   'Duration': '23h 35m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 10697},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '01/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '00:45 02 Mar',
#   'Duration': '13h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 26890},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '1/06/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '13:15',
#   'Arrival_Time': '14:45',
#   'Duration': '1h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No check-in baggage included',
#   'Price': 2175},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → PNQ → COK',
#   'Dep_Time': '23:30',
#   'Arrival_Time': '04:35 28 May',
#   'Duration': '5h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9476},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '24/05/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '21:05',
#   'Arrival_Time': '22:25',
#   'Duration': '1h 20m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3100},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → JAI → BOM → COK',
#   'Dep_Time': '05:30',
#   'Arrival_Time': '04:25 16 Jun',
#   'Duration': '22h 55m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10368},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '18/05/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '22:45',
#   'Arrival_Time': '00:15 19 May',
#   'Duration': '1h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 2017},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '15/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '06:55',
#   'Arrival_Time': '09:30',
#   'Duration': '2h 35m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No check-in baggage included',
#   'Price': 3841},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → NAG → BOM → COK',
#   'Dep_Time': '05:55',
#   'Arrival_Time': '19:15 22 May',
#   'Duration': '37h 20m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 10493},
#  {'Airline': 'SpiceJet',
#   'Date_of_Journey': '09/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '05:45',
#   'Arrival_Time': '08:35',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 5126},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '18/06/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '23:30',
#   'Arrival_Time': '02:20 19 Jun',
#   'Duration': '2h 50m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 3943},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '6/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → BOM → COK',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '19:15 07 Mar',
#   'Duration': '36h 10m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 11552},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '10:00',
#   'Arrival_Time': '19:15',
#   'Duration': '9h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 7934},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '1/03/2019',
#   'Source': 'Mumbai',
#   'Destination': 'Hyderabad',
#   'Route': 'BOM → HYD',
#   'Dep_Time': '15:00',
#   'Arrival_Time': '16:25',
#   'Duration': '1h 25m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 6092},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '12/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → PNQ → COK',
#   'Dep_Time': '23:30',
#   'Arrival_Time': '04:35 13 Jun',
#   'Duration': '5h 5m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 10112},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '9/03/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '09:20',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 6627},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → IDR → BOM → COK',
#   'Dep_Time': '21:25',
#   'Arrival_Time': '12:35 04 Jun',
#   'Duration': '15h 10m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 11507},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '01/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '22:50',
#   'Arrival_Time': '00:45 03 Mar',
#   'Duration': '25h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 26890},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '12/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '05:45',
#   'Arrival_Time': '11:25',
#   'Duration': '5h 40m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13817},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '1/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '21:10',
#   'Arrival_Time': '04:40 02 Apr',
#   'Duration': '7h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13364},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '6/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → DEL → BLR',
#   'Dep_Time': '17:00',
#   'Arrival_Time': '10:45 07 Jun',
#   'Duration': '17h 45m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9187},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '9/05/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '22:05',
#   'Arrival_Time': '00:25 10 May',
#   'Duration': '2h 20m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 5277},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '12/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → AMD → DEL',
#   'Dep_Time': '00:30',
#   'Arrival_Time': '08:45',
#   'Duration': '8h 15m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 13492},
#  {'Airline': 'Air Asia',
#   'Date_of_Journey': '12/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BBI → BLR',
#   'Dep_Time': '06:50',
#   'Arrival_Time': '10:30',
#   'Duration': '3h 40m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5162},
#  {'Airline': 'GoAir',
#   'Date_of_Journey': '9/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '07:00',
#   'Arrival_Time': '12:55',
#   'Duration': '5h 55m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 5897},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '3/06/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '14:15',
#   'Arrival_Time': '16:45',
#   'Duration': '2h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 5510},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '06/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → BOM → DEL',
#   'Dep_Time': '16:55',
#   'Arrival_Time': '10:25 07 Mar',
#   'Duration': '17h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 17261},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '01:30 22 May',
#   'Duration': '13h 50m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 7485},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '21/06/2019',
#   'Source': 'Chennai',
#   'Destination': 'Kolkata',
#   'Route': 'MAA → CCU',
#   'Dep_Time': '11:40',
#   'Arrival_Time': '13:55',
#   'Duration': '2h 15m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4667},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '15/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → DEL → BLR',
#   'Dep_Time': '20:25',
#   'Arrival_Time': '18:00 16 May',
#   'Duration': '21h 35m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 14151},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '16:00',
#   'Arrival_Time': '01:30 28 May',
#   'Duration': '9h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 7048},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '21/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '19:45',
#   'Arrival_Time': '04:25 22 Mar',
#   'Duration': '8h 40m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 12557},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '15/06/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → IDR → BOM → COK',
#   'Dep_Time': '15:05',
#   'Arrival_Time': '01:30 16 Jun',
#   'Duration': '10h 25m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 15965},
#  {'Airline': 'Air India',
#   'Date_of_Journey': '03/03/2019',
#   'Source': 'Banglore',
#   'Destination': 'New Delhi',
#   'Route': 'BLR → CCU → GAU → DEL',
#   'Dep_Time': '11:05',
#   'Arrival_Time': '22:10 07 Mar',
#   'Duration': '35h 5m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 11791},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '3/03/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → HYD → MAA → COK',
#   'Dep_Time': '07:05',
#   'Arrival_Time': '21:20',
#   'Duration': '14h 15m',
#   'Total_Stops': '2 stops',
#   'Additional_Info': 'No info',
#   'Price': 8291},
#  {'Airline': 'IndiGo',
#   'Date_of_Journey': '21/04/2019',
#   'Source': 'Banglore',
#   'Destination': 'Delhi',
#   'Route': 'BLR → DEL',
#   'Dep_Time': '16:55',
#   'Arrival_Time': '19:55',
#   'Duration': '3h',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4990},
#  {'Airline': 'Vistara',
#   'Date_of_Journey': '12/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → DEL → BLR',
#   'Dep_Time': '17:00',
#   'Arrival_Time': '18:50 13 May',
#   'Duration': '25h 50m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9135},
#  {'Airline': 'Air Asia',
#   'Date_of_Journey': '12/04/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BLR',
#   'Dep_Time': '22:50',
#   'Arrival_Time': '01:20 13 Apr',
#   'Duration': '2h 30m',
#   'Total_Stops': 'non-stop',
#   'Additional_Info': 'No info',
#   'Price': 4409},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '21/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '20:00',
#   'Arrival_Time': '04:40 22 May',
#   'Duration': '8h 40m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 10844},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '09:00',
#   'Arrival_Time': '19:00',
#   'Duration': '10h',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 10407},
#  {'Airline': 'Multiple carriers',
#   'Date_of_Journey': '27/05/2019',
#   'Source': 'Delhi',
#   'Destination': 'Cochin',
#   'Route': 'DEL → BOM → COK',
#   'Dep_Time': '07:30',
#   'Arrival_Time': '19:00',
#   'Duration': '11h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'No info',
#   'Price': 9315},
#  {'Airline': 'Jet Airways',
#   'Date_of_Journey': '24/05/2019',
#   'Source': 'Kolkata',
#   'Destination': 'Banglore',
#   'Route': 'CCU → BOM → BLR',
#   'Dep_Time': '21:10',
#   'Arrival_Time': '04:40 25 May',
#   'Duration': '7h 30m',
#   'Total_Stops': '1 stop',
#   'Additional_Info': 'In-flight meal not included',
#   'Price': 9663},
#  ...]

# %%
DB_NAME = "flight"
COLLECTION_NAME = "flight-Data"
CONNECTION_URL = "mongodb+srv://jahid:jahid@cluster0.gidlt.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(5)
# Out:
#                         _id      Airline Date_of_Journey    Source  \
# 0  674338f696fd7cd5b95f6c25       IndiGo      24/03/2019  Banglore
# 1  674338f696fd7cd5b95f6c26    Air India       1/05/2019   Kolkata
# 2  674338f696fd7cd5b95f6c27  Jet Airways       9/06/2019     Delhi
# 3  674338f696fd7cd5b95f6c28       IndiGo      12/05/2019   Kolkata
# 4  674338f696fd7cd5b95f6c29       IndiGo      01/03/2019  Banglore
#
#   Destination                  Route Dep_Time  Arrival_Time Duration  \
# 0   New Delhi              BLR → DEL    22:20  01:10 22 Mar   2h 50m
# 1    Banglore  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m
# 2      Cochin  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h
# 3    Banglore        CCU → NAG → BLR    18:05         23:30   5h 25m
# 4   New Delhi        BLR → NAG → DEL    16:50         21:35   4h 45m
#
#   Total_Stops Additional_Info  Price
# 0    non-stop         No info   3897
# 1     2 stops         No info   7662
# 2     2 stops         No info  13882
# 3      1 stop         No info   6218
# 4      1 stop         No info  13302

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
## If you are getting timeout issue

# import certifi
# client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())
# # TO CREATE THE DATABASE
# data_base = client[DB_NAME]
# collection = data_base[COLLECTION_NAME]
# # TO INSERT DATA INTO THE COLLECTION
# rec = collection.insert_many(data)
